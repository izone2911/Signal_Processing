# %%
# %pip install librosa
# %pip install wavfile
# %pip install torchaudio
# %pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      --------------------------- ------------ 41.0/59.7 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 798.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/260.1 kB ? eta -:--:--
#    -------------- ------------------------- 92.2/260.1 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 225.3/260.1 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  256.0/260.1 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 260.1/260.1 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/74.9 kB ? eta -:--:--
#    ---------------------------------------- 74.9/74.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.7 MB 7.4 MB/s eta 0:00:01
# ...

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

file_path = './Recording.wav'  
samples, sample_rate = librosa.load(file_path, sr=None)  

plt.figure(figsize=(16, 5))
librosa.display.waveshow(samples, sr=sample_rate)
plt.xlabel('Thời gian')
plt.ylabel('Biên độ')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

file_path = './Recording.wav'  
samples, sample_rate = librosa.load(file_path, sr=None)  

plt.figure(figsize=(16, 5))
librosa.display.waveshow(samples[144000:148800], sr=sample_rate)
plt.xlabel('Thời gian')
plt.ylabel('Biên độ')
ticks = [0, 0.005, 0.010, 0.015, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.050, 0.055, 0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.09, 0.095, 0.1, 0.105] 
plt.xticks(ticks)
plt.show()
